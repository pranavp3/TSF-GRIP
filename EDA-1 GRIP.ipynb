# %% [markdown]
# ## Pranav P Pillai
# ### Intern at The Sparks Foundation
# ## Task 3: EDA on Superstore data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv('Downloads\SampleSuperstore.csv')
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
sns.histplot(data=data, x='Discount',y='Profit',bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='Discount', ylabel='Profit'>

# %% [markdown]
# ## Discount and Profit is inversely proportional

# %%
sns.histplot(data=data, x='Sales',y='Profit',bins=10,kde=True)
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Profit'>

# %% [markdown]
# ## Sales and Profit almost directly proportional

# %%
sns.barplot(data['Category'],data['Profit'])
# Out:
# C:\Users\prana\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='Profit'>

# %%
fig, scatter = plt.subplots(figsize = (20,18))
sns.barplot(data['Sub-Category'],data['Profit'])
# Out:
# C:\Users\prana\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sub-Category', ylabel='Profit'>

# %%
sns.barplot(data['Category'],data['Sales'])
# Out:
# C:\Users\prana\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='Sales'>

# %%
sns.barplot(data['Category'],data['Discount'])
# Out:
# C:\Users\prana\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='Discount'>

# %%
fig, scatter = plt.subplots(figsize = (11,7))
sns.countplot(data['Category'],hue=data['Discount'])
# Out:
# C:\Users\prana\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %% [markdown]
# ## Analysis:
# ## Although Furnitures and office supplies has good sales , the profit is low due to high discounts
# ## Rationalise the dsicounts and increase the sales

# %%
sns.barplot(data['Segment'],data['Profit'])
# Out:
# C:\Users\prana\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Segment', ylabel='Profit'>

# %%
sns.barplot(data['Segment'],data['Sales'],hue=data['Category'])
# Out:
# C:\Users\prana\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Segment', ylabel='Sales'>

# %%
sns.countplot(data.Segment,hue=data['Discount'])
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='count'>

# %% [markdown]
# ## Analysis:
# ## HO segment is performing well.
# ## Consumer segment with good sales quantity struggles majorly due to discounts given.
# ## Increase Sales and decrease huge discounts for better performance
# ## Try to sell more technology appliences

# %%
sns.barplot(data['Region'],data['Profit'])
# Out:
# C:\Users\prana\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Region', ylabel='Profit'>

# %%
sns.barplot(data['Region'],data['Sales'],hue=data['Category'])
# Out:
# C:\Users\prana\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Region', ylabel='Sales'>

# %%
sns.countplot(data['Region'],hue=data['Category'])
# Out:
# C:\Users\prana\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %% [markdown]
# ## Analysis:
# ## Although central region has high sales, the profit is less due to lack of sales for technological goods.
# ## Increase sale of Tech goods and decrease high dicounts
